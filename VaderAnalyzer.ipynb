# %%
import nltk
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import matplotlib.pyplot as plt
    
    
data = pd.read_csv("C:\\Users\\shard\\data.csv")
data.columns = ['date','user','text']
data.dropna(inplace=True)

posCount=0
negCount=0
neuCount=0

# function to print sentiments 
# of the sentence. 
def sentiment_scores(sentence): 
  
    global neuCount,posCount,negCount
    # Create a SentimentIntensityAnalyzer object. 
    sid_obj = SentimentIntensityAnalyzer() 
  
    # polarity_scores method of SentimentIntensityAnalyzer 
    # oject gives a sentiment dictionary. 
    # which contains pos, neg, neu, and compound scores. 
    sentiment_dict = sid_obj.polarity_scores(sentence) 
      
    print("Overall sentiment dictionary is : ", sentiment_dict) 
    #print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
    #print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
    #print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive") 
  
    print("Sentence Overall Rated As", end = " ") 
  
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        posCount=posCount+1
        print("Positive") 
  
    elif sentiment_dict['compound'] <= - 0.05 : 
        negCount=negCount+1
        print("Negative") 
  
    else : 
        neuCount=neuCount+1
        print("Neutral") 

        
        

for tweet in data['text']:
    print(tweet)
    sentiment_scores(tweet)
    
sents = [posCount, neuCount, negCount]
plabels = 'Positive' , 'Neutral' , 'Negative'
plt.pie(sents, labels = plabels, autopct='%1.2f')
plt.show()
# Out:
# Tesla is headed to $1000 trader says. Here's one way to ride the rally https://t.co/ImS601Hxlr https://t.co/SS7SVMX0XO
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla Stock on Track to Hit $1000 Per Share Claims Trader https://t.co/HVH2eBXAhB
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.296}
# Sentence Overall Rated As Positive
# Tesla is headed to $1000 trader says. Here's one way to ride the rally $TSLA (via @TradingNation) https://t.co/tF2ouY0VJY
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# #FYI the stock market is having a big day. https://t.co/QZt5xEGQnz @EastBayTimes @mercnews @rexcrum
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.368}
# Sentence Overall Rated As Positive
# #UPDATE The US regained 2.5 million jobs in May and the country's unemployment rate dropped to 13.3% as… https://t.co/gPnwhQol5i
# Overall sentiment dictionary is :  {'neg': 0.139, 'neu': 0.861, 'pos': 0.0, 'compound': -0.4404}
# Sentence Overall Rated As Negative
# U.S. stocks ripped higher Friday heading toward big weekly gains after data showed the economy defied expectation… https://t.co/B5nBuAsPO2
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.34}
# Sentence Overall Rated As Positive
# Baillie Gifford cashed in on Amazon and Tesla before the vast majority of investors. A 33-year partner at the firm… https://t.co/y54je23jqa
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779}
# Sentence Overall Rated As Positive
# Zoom reached a market value of $60 billion this week putting it ahead of the likes of Starbucks and Activision Bli… https://t.co/HaDVETnPRq
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.742, 'pos': 0.258, 'compound': 0.6808}
# Sentence Overall Rated As Positive
# My Latest $TSLA
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Stock futures are up again as investors await the release of employment figures for May. Earnings news is moving re… https://t.co/dw4zyQvjvH
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'compound': 0.1027}
# Sentence Overall Rated As Positive
# Baillie Gifford cashed in on Amazon and Tesla before the vast majority of investors. A 33-year partner at the firm… https://t.co/Z1NAIfksHX
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779}
# Sentence Overall Rated As Positive
# #DowJonesFutures Set To Extend #Coronavirus #Stock Market Rally; #US #NFP Data And #Tesla In Focus   #AvaTrade… https://t.co/3JWuABJ1LU
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.1779}
# Sentence Overall Rated As Positive
# With more than 35 million followers @elonmusk is a prolific tweeter. He has been criticised in the past for his po… https://t.co/9pwK1puajX
# Overall sentiment dictionary is :  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.4215}
# Sentence Overall Rated As Negative
# Tesla’s stock (TSLA) has soared significantly outpacing the market - with the launch of its Dragon spacecraft.
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Zoom and Tesla have grown faster than any other NASDAQ 100 stock this year (story by @dcanellis) https://t.co/bzRlill62W
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# I am beyond excited Elon is back on twitter. Let the Tesla stock volatility resume!
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.4003}
# Sentence Overall Rated As Positive
# Zoom and Tesla have grown faster than any other NASDAQ 100 stock this year (story by @dcanellis) https://t.co/iuyxpSq0ca
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Zoom and Tesla have grown faster than any other NASDAQ 100 stock this year https://t.co/IXnHb7ECTy
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Stock in the Chinese electric vehicle maker NIO jumped more than 15% after Goldman Sachs recommended the shares. https://t.co/ibWKoBXluV
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compound': 0.4588}
# Sentence Overall Rated As Positive
# https://t.co/MFc9aR0AxE
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla will remain in focus across markets after SpaceX’s historic launch of 2 NASA astronauts into space. 🚀
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# @namzo I know. $490 profit will buy more Tesla stock.
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
# Sentence Overall Rated As Positive
# GIMM es el nombre del producto y equipo de T-Systems Iberia con su sede central en Barcelona @22network que digit… https://t.co/16PzErnLyu
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Big week for @elonmusk.
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# The CEO of Tesla and SpaceX just got 1.68 million stock options that provided him with a $770 million payday. https://t.co/hNgnhCPomD
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Shares of electric-car maker Tesla (NASDAQ:TSLA) jumped on Monday rising nearly 8% by the time the market closed.… https://t.co/ZEmbwcd0iW
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.296}
# Sentence Overall Rated As Positive
# Tesla's stock slips 0.2% premarket after soaring 11.5% the past 2 days to close Monday at 3 1/2-mo. high
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Aux États-Unis on peut recevoir un Model Y très rapidement👇https://t.co/KqqpqILDzn
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Merci les stock-options https://t.co/9S3UQMlEHg
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla stock price 📈😂 https://t.co/bhACdNKOHb
# Overall sentiment dictionary is :  {'neg': 0.129, 'neu': 0.612, 'pos': 0.259, 'compound': 0.4404}
# Sentence Overall Rated As Positive
# Tesla stock buying opportunities just died. https://t.co/fauy6qpez6
# Overall sentiment dictionary is :  {'neg': 0.321, 'neu': 0.446, 'pos': 0.232, 'compound': -0.25}
# Sentence Overall Rated As Negative
# Elon Musk has achieved his boyhood dream of launching two American astronauts into space for the first time.
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.25}
# Sentence Overall Rated As Positive
# Elon Musk has achieved his boyhood dream of launching two American astronauts into space for the first time.
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.25}
# Sentence Overall Rated As Positive
# Four Stocks In Or Near Buy Zones Include Netflix; Tesla Is Breaking Out Today Past New Buy Point https://t.co/vTvr1BG3D2
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# For Elon Musk to get his stock options Tesla needs to maintain a market cap of at least $100 billion. So watch it… https://t.co/nSxfIRyMuH
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Analysts believe SpaceX’s success will benefit the electric-car company’s stock. https://t.co/W5NFIQTmt9
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# Sentence Overall Rated As Positive
# Also worth considering lodging companies though maybe not the ones that everyone knows. @carletonenglish found   a… https://t.co/MDKmL2qVfy
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.2263}
# Sentence Overall Rated As Positive
# SpaceX isn't public. So investors bought Virgin Galactic (and Tesla) today instead. (And I'm now humming Intergalac… https://t.co/URQj9tvhUI
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Whenever I mention #Tesla on here. I get the bears come in. (Here's a secret). I bought the stock at $180 and you a… https://t.co/H7wPOvD24A
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Stock chart of the day: $TSLA surges closer to $900 as Morgan Stanley analyst says the weekend success of SpaceX le… https://t.co/378iyp2qgw
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.5719}
# Sentence Overall Rated As Positive
# @LairdElmski @Forbes I don't own any Tesla or any car makers for the record. My article is not Tesla focused. That… https://t.co/xilgOTcBrP
# Overall sentiment dictionary is :  {'neg': 0.094, 'neu': 0.906, 'pos': 0.0, 'compound': -0.2924}
# Sentence Overall Rated As Negative
# The main U.S. stock indexes were near the break-even line despite tension between the U.S. and China and the nation… https://t.co/6OrM2hERRw
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.911, 'pos': 0.089, 'compound': 0.2411}
# Sentence Overall Rated As Positive
# Tesla's stock gains 2.2% premarket after climbing 3.6% on Friday
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.34}
# Sentence Overall Rated As Positive
# Tesla a visiblement beaucoup de Model Y en stock https://t.co/KqqpqILDzn https://t.co/CRPy9grPNP
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla's Stock And SpaceX Launches: Are Traders Looking For A Connection? $TSLA $SPCE https://t.co/UFECSyHIDR #LaunchAmerica
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla CEO Elon Musk has cashed in the first portion of an incentive-based stock options payout for keeping the comp… https://t.co/Toxu77Jglq
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# 📈Stock performance this year:
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla stock is going to soar after successful Space X launch
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.5859}
# Sentence Overall Rated As Positive
# What I’m really seeing going up with this rocket is Tesla stock.
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla's Stock And SpaceX Launches: Are Traders Looking For A Connection? $TSLA $SPCE https://t.co/out6T9tdcX
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# @ArthurFleck74 @MercedesBenz @safelite pure speculation. I'm thinking more @ElonMusk to help pimp up @Tesla Stock as we await #spacexlaunch
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.5209}
# Sentence Overall Rated As Positive
# Elon Musk autorisé à toucher une partie de son énorme rémunération: s'il débloque ses stock-options il empocherait… https://t.co/TBaOCpQzMH
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Controversial multi-billionaire and Tesla CEO Elon Musk gets $770 million thanks to a package he now qualifies for… https://t.co/5P2kdAQ9NK
# Overall sentiment dictionary is :  {'neg': 0.083, 'neu': 0.783, 'pos': 0.134, 'compound': 0.2732}
# Sentence Overall Rated As Positive
# Inside Elon Musk's $780 Million Tesla Payout: Video https://t.co/GZuASN7hGx
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla confirms that CEO Elon Musk will get the first tranche worth nearly $770 million of a stock-based compensatio… https://t.co/uw7uVrS5Bp
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2263}
# Sentence Overall Rated As Positive
# Elon Musk autorisé à toucher une partie de son énorme rémunération: s'il débloque ses stock-options il empocherait… https://t.co/Y6A17XNNel
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla confirms that CEO Elon Musk will get the first tranche worth nearly $770 million of a stock-based compensatio… https://t.co/IdUXTxJQMp
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2263}
# Sentence Overall Rated As Positive
# Tesla CEO Elon Musk has qualified for a compensation package worth about $770 million after the electric vehicle co… https://t.co/ljvVZIy1ff
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2263}
# Sentence Overall Rated As Positive
# Tesla's Musk earns $770M in stock options company confirms (from @AP) ⁦@Tesla⁩ ⁦@elonmusk⁩  https://t.co/zyb27aXaYI
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentence Overall Rated As Neutral
# Tesla CEO Elon Musk has qualified for a compensation package worth about $770 million after the electric vehicle co… https://t.co/r3oYdRbwSu
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2263}
# Sentence Overall Rated As Positive
